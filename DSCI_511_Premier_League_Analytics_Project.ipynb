# %%
import pandas as pd
import requests
import json
import numpy as np
from tabulate import tabulate

def get_and_clean_match_data(hyperlink, season):

  """Fetches match data from FBRef seasons fixture page.
  Cleans it, adds a 'season' column, and returns a pandas DataFrame.

  Args:
    hyperlink: The URL to the FBref fixture page.
    season: A string representing the season (e.g., "2023-2024")."""

  # Fetch the data from the hyperlink
  match_data = pd.read_html(hyperlink)[0]  # First table on page is fixtures table

  # Drop unnecessary columns
  match_data = match_data.drop(columns=['Wk','Day','Time','Attendance','Venue','Referee','Match Report','Notes'])

  # Drop rows where all values are missing ie divider rows
  match_data.dropna(axis=0, how='all', subset=None, inplace=True)

  # Extract home and away scores
  match_data['score_home'] = match_data['Score'].str[0]
  match_data['score_away'] = match_data['Score'].str[2]

  # Convert scores to numeric to enable calculations later
  match_data['score_home'] = pd.to_numeric(match_data['score_home'])
  match_data['score_away'] = pd.to_numeric(match_data['score_away'])

  # Labels rows for season based on 'season' string parameter
  match_data['season'] = season

  return match_data  # Return the cleaned DataFrame


def save_to_json(data, filename):

  """
  Function to save data to JSON file
  Args:
    data: The data to be saved
    filename: The name of the JSON file to save the data to
  """

  if data:  # Only save if data is not empty
      with open(filename, 'w') as file:
          json.dump(data, file, indent=4)
      print(f"Data successfully saved to '{filename}'")
  else:
      print(f"No data to save for '{filename}'")

# Function to fetch data from Odds API
def fetch_odds_data(API_URL, start_date, end_date):

    """
    Function to fetch odds for Odds API. Returns a JSON object.
    Args:
        API_URL: The URL of the Odds API.
        start_date: The start date for Premier League fixtures.
        end_date: The end date for Premier League fixtures.
    """

    API_KEY = "613fd2af3ec961ddefb9b7e0e058bd69"

    start_datetime = start_date+'T00:00:00Z'
    end_datetime = end_date+'T00:00:00Z'

    params = {
        "apiKey": API_KEY,
        "regions": "uk",
        "markets": "h2h",
        "bookmakers": "paddypower",
        "commenceTimeFrom": start_datetime,
        "commenceTimeTo": end_datetime
    }
    response = requests.get(API_URL, params=params)
    if response.status_code == 200:
        odds_data = response.json()
        save_to_json(odds_data, "match_odds_data.json")
        return odds_data
    else:
        print(f"Error fetching odds data: {response.status_code}")
        return {}

def extract_odds(odds_data):

  """
  Function to turn odds in json format into a dataframe.
  Does not allow overwite if odds alreadty exist for that fixture in the dataframe
  """

  extract_odds = []

  #loop through odds_data
  for match in odds_data:

      #Extract fixture data and teams
      match_data = {
          'Date': pd.to_datetime(match['commence_time']).date(),
          'Home': match['home_team'],
          'Away': match['away_team']
      }

      #Ensure bookmaker dictionary is not empty. This occurs sometimes with Odds API.
      if not match['bookmakers']:
          continue

      #Extract odds for each match
      x = 0
      for outcome in match['bookmakers'][0]['markets'][0]['outcomes']:
          if x == 0:
              match_data['odds_home'] = outcome['price']
          if x == 1:
              match_data['odds_draw'] = outcome['price']
          if x == 2:
              match_data['odds_away'] = outcome['price']
          x += 1

      #add fixture dictionary to list
      extract_odds.append(match_data)

  #Create a dataframe from list of fixtures.
  #Logic to ensure previous odds are not overwritten. This is important because OddsAPI does not provide historical odds (for free). Also odds that update during a game can be highly-skewed, like when a team is losing and game is about to end. So we want to preserve odds acquired before games start.
  try:
      odds_df
  except NameError:  # Use NameError to check for variable existence
      odds_df = pd.DataFrame(extract_odds)
  else:
      extract_df = pd.DataFrame(extract_odds)
      odds_df = pd.concat([odds_df, extract_df], ignore_index=True)
      odds_df = odds_df.drop_duplicates(subset=['Date', 'Home', 'Away'], keep='first')

  return odds_df

def odds_to_metrics(odds_df, baseline):

  """
  Function enrich odds dataframe with metrics.
  Read more about Poisson distribution and the methodology used here:
  https://www.pinnacle.com/betting-resources/en/soccer/poisson-distribution-predict-the-score-in-soccer-betting/md62mlxumkmxz6a8
  """

  # Step 1: Convert odds to implied probabilities
  odds_df['p_H'] = 1 / odds_df['odds_home']
  odds_df['p_D'] = 1 / odds_df['odds_draw']
  odds_df['p_A'] = 1 / odds_df['odds_away']

  # Step 2: Adjust for the bookmaker’s margin (de‐overround)
  odds_df['S'] = odds_df['p_H'] + odds_df['p_D'] + odds_df['p_A']
  odds_df['P_H'] = odds_df['p_H'] / odds_df['S']
  odds_df['P_A'] = odds_df['p_A'] / odds_df['S']

  # Step 3: Estimate expected goals using a Poisson-inspired adjustment
  # The formula shifts the baseline by half the log ratio of home vs. away win probabilities
  odds_df['odds_home_xG'] = np.round(baseline + 0.5 * np.log(odds_df['P_H'] / odds_df['P_A']),1)
  odds_df['odds_away_xG'] = np.round(baseline - 0.5 * np.log(odds_df['P_H'] / odds_df['P_A']),1)

  # Step 4: Calculate clean sheet likelihoods using the Poisson probability for 0 goals
  # For the home team: the clean sheet likelihood is the probability that the away team scores 0 goals
  odds_df['home_CS%'] = np.round(np.exp(-odds_df['odds_away_xG'])*100,1)
  # For the away team: the clean sheet likelihood is the probability that the home team scores 0 goals
  odds_df['away_CS%'] = np.round(np.exp(-odds_df['odds_home_xG'])*100,1)

  # Drop intermediate columns
  odds_df = odds_df.drop(columns=['p_H', 'p_D', 'p_A', 'S', 'P_H', 'P_A'])

  return odds_df

def calculate_ewma(df, column, span, group_by_col):
    """
    Calculates exponentially weighted moving average (EWMA) for a given column.

    Args:
        df: The DataFrame containing the data.
        column (str): The name of the column to calculate EWMA for.
        span (int): The span for the EWMA calculation ie. the number of historical games to consider.
        group_by_col (str): The column to group by. For this dataset, we are grouping by home and away team.
        adjust: set to True ie. more recent values hold exponentially more weight.

    Returns:
        pd.Series: The EWMA values for the specified column.
    """
    return df.groupby([group_by_col])[column].transform(lambda x: round(x.ewm(span=span, adjust=True).mean(),1))

# %%
#=============================================================
#Get Premier League fixture data
#=============================================================

# Dictionary of FBRef fixtures pages to scrape
season_links = {
    "2024-2025": 'https://fbref.com/en/comps/9/schedule/Premier-League-Scores-and-Fixtures',
    "2023-2024": 'https://fbref.com/en/comps/9/2023-2024/schedule/2023-2024-Premier-League-Scores-and-Fixtures',
}

# Iterate through the links dict, extract data, and store all season match data in a single dataframe
matches = pd.concat(
    (get_and_clean_match_data(hyperlink, season) for season, hyperlink in season_links.items())
)
# Sort by 'Date' column in ascending order
matches = matches.sort_values(by='Date', ascending=True)

# %%
#=============================================================
#Get odds data + created a dataframe enriched with metrics
#=============================================================

#Get bookmaker odds and turn them into expected goals
ODDS_API_URL = "https://api.the-odds-api.com/v4/sports/soccer_epl/odds"
odds_data = fetch_odds_data(ODDS_API_URL,'2024-08-16','2025-05-25')

# Calculate baseline average expected goals per team
baseline = matches[['score_home', 'score_away']].sum().sum() / len(2*matches)

#Transform odds into expected goals using Poisson distribution
odds_df = odds_to_metrics(extract_odds(odds_data), baseline)
# Out:
# Data successfully saved to 'match_odds_data.json'

# %%
#======================================================
#Create a new merged table. Requires cleaning and renaming.
#Only done for 2024/2025 season. Might have to revisit.
#======================================================

# Make date column a date
matches['Date'] = pd.to_datetime(matches['Date']).dt.date

#make sure 'Home' and 'Away' columns are string with no leading and trailing zeros
matches['Home'] = matches['Home'].astype(str).str.strip()
matches['Away'] = matches['Away'].astype(str).str.strip()
odds_df['Home'] = odds_df['Home'].astype(str).str.strip()
odds_df['Away'] = odds_df['Away'].astype(str).str.strip()

# Update team names in odds table
odds_df.loc[:, ['Home', 'Away']] = odds_df.loc[:, ['Home', 'Away']].replace({
    'Wolverhampton Wanderers': 'Wolves',
    'Brighton and Hove Albion': 'Brighton',
    'West Ham United' : 'West Ham',
    'Tottenham Hotspur': 'Tottenham',
})

# Update team names in matches table
matches.loc[:, ['Home', 'Away']] = matches.loc[:, ['Home', 'Away']].replace({
    'Newcastle Utd': 'Newcastle United',
    "Nott'ham Forest": 'Nottingham Forest',
    'Manchester Utd': 'Manchester United'
})

# Select the desired columns from odds_df
odds_df_subset = odds_df[['Date', 'Home', 'Away', 'odds_home_xG', 'odds_away_xG', 'home_CS%', 'away_CS%']]

# Merge the subset with matches
match_merged = pd.merge(matches, odds_df_subset, on=['Date', 'Home', 'Away'], how='left')

# %%
#==========================================================
#Add new caclulated columns to merged table + export to csv
#==========================================================

# Rename xG columns
match_merged = match_merged.rename(columns={'xG': 'xG_home', 'xG.1': 'xG_away'})

# Calculate moving averages over past 10 games with decay for goals scored and xG
for col, group_col in [('score_home', 'Home'), ('score_away', 'Away'),
                         ('xG_home', 'Home'), ('xG_away', 'Away')]:
    match_merged[col + '_ewma'] = calculate_ewma(match_merged, col, span=10, group_by_col=group_col)

# Calculate diff
match_merged['xG_home_diff'] = np.round(match_merged['score_home'] - match_merged['xG_home'],1)
match_merged['xG_away_diff'] = np.round(match_merged['score_away'] - match_merged['xG_away'],1)
match_merged['ewma_diff_home_xG'] = np.round(match_merged['score_home_ewma'] - match_merged['xG_home_ewma'],1)
match_merged['ewma_diff_away_xG'] = np.round(match_merged['score_away_ewma'] - match_merged['xG_away_ewma'],1)

# Reorder merged table
desired_order = ['season','Date', 'Home', 'Score', 'Away',
                 'home_CS%', 'odds_home_xG' ,'score_home_ewma', 'xG_home_ewma', 'ewma_diff_home_xG',
                 'away_CS%', 'odds_away_xG', 'score_away_ewma', 'xG_away_ewma', 'ewma_diff_away_xG',
                 'score_home','xG_home', 'xG_home_diff',
                 'score_away','xG_away', 'xG_away_diff',
                 ]

match_merged = match_merged[desired_order]

# Export to csv
match_merged.to_csv('EPL_fantasy_metrics.csv', index=False)

# %%
with pd.option_context("display.max_rows", None):
  print(tabulate(match_merged[match_merged['season']=='2024-2025'].head(400), headers='keys', tablefmt='pretty'))
# Out:
# +-----+-----------+------------+-------------------+-------+-------------------+----------+--------------+-----------------+--------------+-------------------+----------+--------------+-----------------+--------------+-------------------+------------+---------+--------------+------------+---------+--------------+
# |     |  season   |    Date    |       Home        | Score |       Away        | home_CS% | odds_home_xG | score_home_ewma | xG_home_ewma | ewma_diff_home_xG | away_CS% | odds_away_xG | score_away_ewma | xG_away_ewma | ewma_diff_away_xG | score_home | xG_home | xG_home_diff | score_away | xG_away | xG_away_diff |
# +-----+-----------+------------+-------------------+-------+-------------------+----------+--------------+-----------------+--------------+-------------------+----------+--------------+-----------------+--------------+-------------------+------------+---------+--------------+------------+---------+--------------+
# | 380 | 2024-2025 | 2024-08-16 | Manchester United |  1–0  |      Fulham       |   nan    |     nan      |       1.7       |     1.8      |       -0.1        |   nan    |     nan      |       1.4       |     1.3      |        0.1        |    1.0     |   2.4   |     -1.4     |    0.0     |   0.4   |     -0.4     |
# | 381 | 2024-2025 | 2024-08-17 |   Ipswich Town    |  0–2  |     Liverpool     |   nan    |     nan      |       0.0       |     0.5      |       -0.5        |   nan    |     nan      |       2.1       |     2.0      |        0.1        |    0.0     |   0.5   |     -0.5     |    2.0     |   2.6   |     -0.6     |
# | 382 | 2024-2025 | 2024-08-17 | Newcastle United  |  1–0  |    Southampton    |   nan    |     nan      |       2.4       |     2.2      |        0.2        |   nan    |     nan      |       0.0       |     1.8      |       -1.8        |    1.0     |   0.3   |     0.7      |    0.0     |   1.8   |     -1.8     |
# | 383 | 2024-2025 | 2024-08-17 | Nottingham Forest |  1–1  |    Bournemouth    |   nan    |     nan      |       1.4       |     1.5      |       -0.1        |   nan    |     nan      |       1.1       |     1.4      |       -0.3        |    1.0     |   1.3   |     -0.3     |    1.0     |   1.2   |     -0.2     |
# | 384 | 2024-2025 | 2024-08-17 |      Everton      |  0–3  |     Brighton      |   nan    |     nan      |       1.0       |     1.3      |       -0.3        |   nan    |     nan      |       1.3       |     1.2      |        0.1        |    0.0     |   0.5   |     -0.5     |    3.0     |   1.4   |     1.6      |
# | 385 | 2024-2025 | 2024-08-17 |      Arsenal      |  2–0  |      Wolves       |   nan    |     nan      |       2.5       |     2.3      |        0.2        |   nan    |     nan      |       0.8       |     0.9      |       -0.1        |    2.0     |   1.2   |     0.8      |    0.0     |   0.5   |     -0.5     |
# | 386 | 2024-2025 | 2024-08-17 |     West Ham      |  1–2  |    Aston Villa    |   nan    |     nan      |       1.5       |     1.7      |       -0.2        |   nan    |     nan      |       1.4       |     1.2      |        0.2        |    1.0     |   2.3   |     -1.3     |    2.0     |   2.0   |     0.0      |
# | 387 | 2024-2025 | 2024-08-18 |      Chelsea      |  0–2  |  Manchester City  |   nan    |     nan      |       2.5       |     2.3      |        0.2        |   nan    |     nan      |       2.5       |     1.8      |        0.7        |    0.0     |   1.0   |     -1.0     |    2.0     |   0.8   |     1.2      |
# | 388 | 2024-2025 | 2024-08-18 |     Brentford     |  2–1  |  Crystal Palace   |   nan    |     nan      |       1.4       |     1.4      |        0.0        |   nan    |     nan      |       1.2       |     1.3      |       -0.1        |    2.0     |   1.6   |     0.4      |    1.0     |   1.2   |     -0.2     |
# | 389 | 2024-2025 | 2024-08-19 |  Leicester City   |  1–1  |     Tottenham     |   nan    |     nan      |       1.0       |     1.0      |        0.0        |   nan    |     nan      |       1.5       |     1.6      |       -0.1        |    1.0     |   1.0   |     0.0      |    1.0     |   1.2   |     -0.2     |
# | 390 | 2024-2025 | 2024-08-24 |      Fulham       |  2–1  |  Leicester City   |   nan    |     nan      |       1.4       |     1.3      |        0.1        |   nan    |     nan      |       1.0       |     0.6      |        0.4        |    2.0     |   1.8   |     0.2      |    1.0     |   0.6   |     0.4      |
# | 391 | 2024-2025 | 2024-08-24 |  Crystal Palace   |  0–2  |     West Ham      |   nan    |     nan      |       2.5       |     1.7      |        0.8        |   nan    |     nan      |       1.5       |     1.2      |        0.3        |    0.0     |   1.3   |     -1.3     |    2.0     |   1.4   |     0.6      |
# | 392 | 2024-2025 | 2024-08-24 |  Manchester City  |  4–1  |   Ipswich Town    |   nan    |     nan      |       3.3       |     2.8      |        0.5        |   nan    |     nan      |       1.0       |     0.3      |        0.7        |    4.0     |   3.3   |     0.7      |    1.0     |   0.3   |     0.7      |
# | 393 | 2024-2025 | 2024-08-24 |    Southampton    |  0–1  | Nottingham Forest |   nan    |     nan      |       0.0       |     0.1      |       -0.1        |   nan    |     nan      |       1.3       |     1.6      |       -0.3        |    0.0     |   0.1   |     -0.1     |    1.0     |   2.2   |     -1.2     |
# | 394 | 2024-2025 | 2024-08-24 |    Aston Villa    |  0–2  |      Arsenal      |   nan    |     nan      |       1.9       |     1.8      |        0.1        |   nan    |     nan      |       2.3       |     1.5      |        0.8        |    0.0     |   1.2   |     -1.2     |    2.0     |   0.9   |     1.1      |
# | 395 | 2024-2025 | 2024-08-24 |     Tottenham     |  4–0  |      Everton      |   nan    |     nan      |       2.2       |     2.2      |        0.0        |   nan    |     nan      |       0.6       |     1.1      |       -0.5        |    4.0     |   2.4   |     1.6      |    0.0     |   1.0   |     -1.0     |
# | 396 | 2024-2025 | 2024-08-24 |     Brighton      |  2–1  | Manchester United |   nan    |     nan      |       1.1       |     1.6      |       -0.5        |   nan    |     nan      |       1.4       |     1.2      |        0.2        |    2.0     |   2.1   |     -0.1     |    1.0     |   1.4   |     -0.4     |
# | 397 | 2024-2025 | 2024-08-25 |    Bournemouth    |  1–1  | Newcastle United  |   nan    |     nan      |       1.6       |     1.6      |        0.0        |   nan    |     nan      |       2.0       |     1.8      |        0.2        |    1.0     |   2.2   |     -1.2     |    1.0     |   1.6   |     -0.6     |
# | 398 | 2024-2025 | 2024-08-25 |      Wolves       |  2–6  |      Chelsea      |   nan    |     nan      |       1.3       |     1.3      |        0.0        |   nan    |     nan      |       2.6       |     1.5      |        1.1        |    2.0     |   1.9   |     0.1      |    6.0     |   1.6   |     4.4      |
# | 399 | 2024-2025 | 2024-08-25 |     Liverpool     |  2–0  |     Brentford     |   nan    |     nan      |       2.3       |     3.0      |       -0.7        |   nan    |     nan      |       1.5       |     1.2      |        0.3        |    2.0     |   2.5   |     -0.5     |    0.0     |   0.5   |     -0.5     |
# | 400 | 2024-2025 | 2024-08-31 |     West Ham      |  1–3  |  Manchester City  |   nan    |     nan      |       1.4       |     1.5      |       -0.1        |   nan    |     nan      |       2.6       |     2.0      |        0.6        |    1.0     |   0.7   |     0.3      |    3.0     |   3.0   |     0.0      |
# | 401 | 2024-2025 | 2024-08-31 |     Brentford     |  3–1  |    Southampton    |   nan    |     nan      |       1.7       |     1.6      |        0.1        |   nan    |     nan      |       0.6       |     1.6      |       -1.0        |    3.0     |   2.8   |     0.2      |    1.0     |   1.5   |     -0.5     |
# | 402 | 2024-2025 | 2024-08-31 | Nottingham Forest |  1–1  |      Wolves       |   nan    |     nan      |       1.3       |     1.4      |       -0.1        |   nan    |     nan      |       0.9       |     0.8      |        0.1        |    1.0     |   1.0   |     0.0      |    1.0     |   0.7   |     0.3      |
# | 403 | 2024-2025 | 2024-08-31 |  Leicester City   |  1–2  |    Aston Villa    |   nan    |     nan      |       1.0       |     0.7      |        0.3        |   nan    |     nan      |       1.5       |     1.2      |        0.3        |    1.0     |   0.4   |     0.6      |    2.0     |   1.4   |     0.6      |
# | 404 | 2024-2025 | 2024-08-31 |      Everton      |  2–3  |    Bournemouth    |   nan    |     nan      |       1.2       |     1.4      |       -0.2        |   nan    |     nan      |       1.4       |     1.6      |       -0.2        |    2.0     |   1.8   |     0.2      |    3.0     |   2.4   |     0.6      |
# | 405 | 2024-2025 | 2024-08-31 |      Arsenal      |  1–1  |     Brighton      |   nan    |     nan      |       2.2       |     2.2      |        0.0        |   nan    |     nan      |       1.2       |     1.3      |       -0.1        |    1.0     |   2.1   |     -1.1     |    1.0     |   1.7   |     -0.7     |
# | 406 | 2024-2025 | 2024-08-31 |   Ipswich Town    |  1–1  |      Fulham       |   nan    |     nan      |       0.6       |     0.4      |        0.2        |   nan    |     nan      |       1.3       |     1.2      |        0.1        |    1.0     |   0.4   |     0.6      |    1.0     |   0.9   |     0.1      |
# | 407 | 2024-2025 | 2024-09-01 | Newcastle United  |  2–1  |     Tottenham     |   nan    |     nan      |       2.4       |     2.1      |        0.3        |   nan    |     nan      |       1.4       |     1.5      |       -0.1        |    2.0     |   1.8   |     0.2      |    1.0     |   1.2   |     -0.2     |
# | 408 | 2024-2025 | 2024-09-01 |      Chelsea      |  1–1  |  Crystal Palace   |   nan    |     nan      |       2.2       |     2.3      |       -0.1        |   nan    |     nan      |       1.2       |     1.1      |        0.1        |    1.0     |   2.4   |     -1.4     |    1.0     |   0.5   |     0.5      |
# | 409 | 2024-2025 | 2024-09-01 | Manchester United |  0–3  |     Liverpool     |   nan    |     nan      |       1.4       |     1.7      |       -0.3        |   nan    |     nan      |       2.2       |     1.9      |        0.3        |    0.0     |   1.4   |     -1.4     |    3.0     |   1.8   |     1.2      |
# | 410 | 2024-2025 | 2024-09-14 |    Aston Villa    |  3–2  |      Everton      |   nan    |     nan      |       2.1       |     1.9      |        0.2        |   nan    |     nan      |       0.9       |     1.1      |       -0.2        |    3.0     |   2.1   |     0.9      |    2.0     |   0.9   |     1.1      |
# | 411 | 2024-2025 | 2024-09-14 |    Bournemouth    |  0–1  |      Chelsea      |   nan    |     nan      |       1.3       |     1.6      |       -0.3        |   nan    |     nan      |       2.3       |     1.3      |        1.0        |    0.0     |   1.7   |     -1.7     |    1.0     |   0.8   |     0.2      |
# | 412 | 2024-2025 | 2024-09-14 |      Fulham       |  1–1  |     West Ham      |   nan    |     nan      |       1.3       |     1.3      |        0.0        |   nan    |     nan      |       1.4       |     1.1      |        0.3        |    1.0     |   1.5   |     -0.5     |    1.0     |   0.8   |     0.2      |
# | 413 | 2024-2025 | 2024-09-14 |  Crystal Palace   |  2–2  |  Leicester City   |   nan    |     nan      |       2.4       |     1.8      |        0.6        |   nan    |     nan      |       1.6       |     0.9      |        0.7        |    2.0     |   2.5   |     -0.5     |    2.0     |   1.2   |     0.8      |
# | 414 | 2024-2025 | 2024-09-14 |  Manchester City  |  2–1  |     Brentford     |   nan    |     nan      |       3.0       |     2.7      |        0.3        |   nan    |     nan      |       1.4       |     1.2      |        0.2        |    2.0     |   2.1   |     -0.1     |    1.0     |   1.0   |     0.0      |
# | 415 | 2024-2025 | 2024-09-14 |    Southampton    |  0–3  | Manchester United |   nan    |     nan      |       0.0       |     0.6      |       -0.6        |   nan    |     nan      |       1.7       |     1.5      |        0.2        |    0.0     |   1.1   |     -1.1     |    3.0     |   2.6   |     0.4      |
# | 416 | 2024-2025 | 2024-09-14 |     Brighton      |  0–0  |   Ipswich Town    |   nan    |     nan      |       0.9       |     1.6      |       -0.7        |   nan    |     nan      |       0.4       |     0.3      |        0.1        |    0.0     |   1.6   |     -1.6     |    0.0     |   0.3   |     -0.3     |
# | 417 | 2024-2025 | 2024-09-14 |     Liverpool     |  0–1  | Nottingham Forest |   nan    |     nan      |       1.9       |     2.6      |       -0.7        |   nan    |     nan      |       1.3       |     1.4      |       -0.1        |    0.0     |   0.9   |     -0.9     |    1.0     |   0.4   |     0.6      |
# | 418 | 2024-2025 | 2024-09-15 |     Tottenham     |  0–1  |      Arsenal      |   nan    |     nan      |       1.8       |     1.9      |       -0.1        |   nan    |     nan      |       2.1       |     1.4      |        0.7        |    0.0     |   0.7   |     -0.7     |    1.0     |   0.7   |     0.3      |
# | 419 | 2024-2025 | 2024-09-15 |      Wolves       |  1–2  | Newcastle United  |   nan    |     nan      |       1.2       |     1.3      |       -0.1        |   nan    |     nan      |       2.0       |     1.8      |        0.2        |    1.0     |   1.2   |     -0.2     |    2.0     |   1.5   |     0.5      |
# | 420 | 2024-2025 | 2024-09-21 |  Crystal Palace   |  0–0  | Manchester United |   nan    |     nan      |       2.0       |     1.7      |        0.3        |   nan    |     nan      |       1.4       |     1.5      |       -0.1        |    0.0     |   1.0   |     -1.0     |    0.0     |   1.6   |     -1.6     |
# | 421 | 2024-2025 | 2024-09-21 |    Aston Villa    |  3–1  |      Wolves       |   nan    |     nan      |       2.3       |     1.9      |        0.4        |   nan    |     nan      |       0.9       |     0.8      |        0.1        |    3.0     |   1.7   |     1.3      |    1.0     |   0.5   |     0.5      |
# | 422 | 2024-2025 | 2024-09-21 |      Fulham       |  3–1  | Newcastle United  |   nan    |     nan      |       1.6       |     1.5      |        0.1        |   nan    |     nan      |       1.8       |     1.7      |        0.1        |    3.0     |   2.2   |     0.8      |    1.0     |   1.5   |     -0.5     |
# | 423 | 2024-2025 | 2024-09-21 |     Tottenham     |  3–1  |     Brentford     |   nan    |     nan      |       2.0       |     2.2      |       -0.2        |   nan    |     nan      |       1.3       |     1.1      |        0.2        |    3.0     |   3.5   |     -0.5     |    1.0     |   0.8   |     0.2      |
# | 424 | 2024-2025 | 2024-09-21 |  Leicester City   |  1–1  |      Everton      |   nan    |     nan      |       1.0       |     0.7      |        0.3        |   nan    |     nan      |       0.9       |     1.1      |       -0.2        |    1.0     |   0.7   |     0.3      |    1.0     |   1.1   |     -0.1     |
# | 425 | 2024-2025 | 2024-09-21 |     Liverpool     |  3–0  |    Bournemouth    |   nan    |     nan      |       2.1       |     2.5      |       -0.4        |   nan    |     nan      |       1.2       |     1.5      |       -0.3        |    3.0     |   2.0   |     1.0      |    0.0     |   1.1   |     -1.1     |
# | 426 | 2024-2025 | 2024-09-21 |     West Ham      |  0–3  |      Chelsea      |   nan    |     nan      |       1.2       |     1.4      |       -0.2        |   nan    |     nan      |       2.4       |     1.5      |        0.9        |    0.0     |   0.9   |     -0.9     |    3.0     |   2.2   |     0.8      |
# | 427 | 2024-2025 | 2024-09-21 |    Southampton    |  1–1  |   Ipswich Town    |   nan    |     nan      |       0.4       |     1.4      |       -1.0        |   nan    |     nan      |       0.7       |     0.8      |       -0.1        |    1.0     |   2.4   |     -1.4     |    1.0     |   1.6   |     -0.6     |
# | 428 | 2024-2025 | 2024-09-22 |     Brighton      |  2–2  | Nottingham Forest |   nan    |     nan      |       1.1       |     1.5      |       -0.4        |   nan    |     nan      |       1.4       |     1.4      |        0.0        |    2.0     |   1.0   |     1.0      |    2.0     |   1.4   |     0.6      |
# | 429 | 2024-2025 | 2024-09-22 |  Manchester City  |  2–2  |      Arsenal      |   nan    |     nan      |       2.8       |     2.6      |        0.2        |   nan    |     nan      |       2.1       |     1.3      |        0.8        |    2.0     |   2.1   |     -0.1     |    2.0     |   0.7   |     1.3      |
# | 430 | 2024-2025 | 2024-09-28 |      Wolves       |  1–2  |     Liverpool     |   nan    |     nan      |       1.2       |     1.1      |        0.1        |   nan    |     nan      |       2.2       |     2.0      |        0.2        |    1.0     |   0.6   |     0.4      |    2.0     |   2.5   |     -0.5     |
# | 431 | 2024-2025 | 2024-09-28 | Nottingham Forest |  0–1  |      Fulham       |   nan    |     nan      |       1.1       |     1.3      |       -0.2        |   nan    |     nan      |       1.3       |     1.2      |        0.1        |    0.0     |   0.8   |     -0.8     |    1.0     |   1.3   |     -0.3     |
# | 432 | 2024-2025 | 2024-09-28 |      Arsenal      |  4–2  |  Leicester City   |   nan    |     nan      |       2.5       |     2.6      |       -0.1        |   nan    |     nan      |       1.7       |     0.7      |        1.0        |    4.0     |   4.4   |     -0.4     |    2.0     |   0.3   |     1.7      |
# | 433 | 2024-2025 | 2024-09-28 |     Brentford     |  1–1  |     West Ham      |   nan    |     nan      |       1.6       |     1.4      |        0.2        |   nan    |     nan      |       1.3       |     1.1      |        0.2        |    1.0     |   0.4   |     0.6      |    1.0     |   1.0   |     0.0      |
# | 434 | 2024-2025 | 2024-09-28 |      Chelsea      |  4–2  |     Brighton      |   nan    |     nan      |       2.5       |     2.6      |       -0.1        |   nan    |     nan      |       1.4       |     1.3      |        0.1        |    4.0     |   4.2   |     -0.2     |    2.0     |   1.1   |     0.9      |
# | 435 | 2024-2025 | 2024-09-28 |      Everton      |  2–1  |  Crystal Palace   |   nan    |     nan      |       1.4       |     1.3      |        0.1        |   nan    |     nan      |       1.1       |     1.1      |        0.0        |    2.0     |   0.9   |     1.1      |    1.0     |   0.9   |     0.1      |
# | 436 | 2024-2025 | 2024-09-28 | Newcastle United  |  1–1  |  Manchester City  |   nan    |     nan      |       2.1       |     2.0      |        0.1        |   nan    |     nan      |       2.3       |     1.8      |        0.5        |    1.0     |   1.6   |     -0.6     |    1.0     |   0.9   |     0.1      |
# | 437 | 2024-2025 | 2024-09-29 | Manchester United |  0–3  |     Tottenham     |   nan    |     nan      |       1.1       |     1.6      |       -0.5        |   nan    |     nan      |       1.7       |     2.0      |       -0.3        |    0.0     |   1.0   |     -1.0     |    3.0     |   4.4   |     -1.4     |
# | 438 | 2024-2025 | 2024-09-29 |   Ipswich Town    |  2–2  |    Aston Villa    |   nan    |     nan      |       1.1       |     0.7      |        0.4        |   nan    |     nan      |       1.6       |     1.1      |        0.5        |    2.0     |   1.2   |     0.8      |    2.0     |   0.8   |     1.2      |
# | 439 | 2024-2025 | 2024-09-30 |    Bournemouth    |  3–1  |    Southampton    |   nan    |     nan      |       1.6       |     1.6      |        0.0        |   nan    |     nan      |       0.7       |     1.2      |       -0.5        |    3.0     |   1.3   |     1.7      |    1.0     |   0.6   |     0.4      |
# | 440 | 2024-2025 | 2024-10-05 |  Crystal Palace   |  0–1  |     Liverpool     |   nan    |     nan      |       1.6       |     1.5      |        0.1        |   nan    |     nan      |       2.0       |     1.9      |        0.1        |    0.0     |   0.6   |     -0.6     |    1.0     |   1.4   |     -0.4     |
# | 441 | 2024-2025 | 2024-10-05 |  Manchester City  |  3–2  |      Fulham       |   nan    |     nan      |       2.9       |     2.4      |        0.5        |   nan    |     nan      |       1.4       |     1.5      |       -0.1        |    3.0     |   1.6   |     1.4      |    2.0     |   2.6   |     -0.6     |
# | 442 | 2024-2025 | 2024-10-05 |     Brentford     |  5–3  |      Wolves       |   nan    |     nan      |       2.2       |     1.9      |        0.3        |   nan    |     nan      |       1.3       |     0.8      |        0.5        |    5.0     |   4.2   |     0.8      |    3.0     |   1.0   |     2.0      |
# | 443 | 2024-2025 | 2024-10-05 |     West Ham      |  4–1  |   Ipswich Town    |   nan    |     nan      |       1.7       |     1.8      |       -0.1        |   nan    |     nan      |       0.8       |     0.7      |        0.1        |    4.0     |   3.6   |     0.4      |    1.0     |   0.6   |     0.4      |
# | 444 | 2024-2025 | 2024-10-05 |  Leicester City   |  1–0  |    Bournemouth    |   nan    |     nan      |       1.0       |     0.7      |        0.3        |   nan    |     nan      |       1.0       |     1.6      |       -0.6        |    1.0     |   0.8   |     0.2      |    0.0     |   2.1   |     -2.1     |
# | 445 | 2024-2025 | 2024-10-05 |      Everton      |  0–0  | Newcastle United  |   nan    |     nan      |       1.1       |     1.2      |       -0.1        |   nan    |     nan      |       1.5       |     1.8      |       -0.3        |    0.0     |   0.7   |     -0.7     |    0.0     |   2.1   |     -2.1     |
# | 446 | 2024-2025 | 2024-10-05 |      Arsenal      |  3–1  |    Southampton    |   nan    |     nan      |       2.6       |     2.7      |       -0.1        |   nan    |     nan      |       0.8       |     1.0      |       -0.2        |    3.0     |   2.8   |     0.2      |    1.0     |   0.6   |     0.4      |
# | 447 | 2024-2025 | 2024-10-06 |    Aston Villa    |  0–0  | Manchester United |   nan    |     nan      |       1.9       |     1.6      |        0.3        |   nan    |     nan      |       1.2       |     1.3      |       -0.1        |    0.0     |   0.5   |     -0.5     |    0.0     |   0.6   |     -0.6     |
# | 448 | 2024-2025 | 2024-10-06 |      Chelsea      |  1–1  | Nottingham Forest |   nan    |     nan      |       2.3       |     2.6      |       -0.3        |   nan    |     nan      |       1.3       |     1.3      |        0.0        |    1.0     |   2.3   |     -1.3     |    1.0     |   0.9   |     0.1      |
# | 449 | 2024-2025 | 2024-10-06 |     Brighton      |  3–2  |     Tottenham     |   nan    |     nan      |       1.5       |     1.5      |        0.0        |   nan    |     nan      |       1.8       |     1.9      |       -0.1        |    3.0     |   1.8   |     1.2      |    2.0     |   1.3   |     0.7      |
# | 450 | 2024-2025 | 2024-10-19 | Manchester United |  2–1  |     Brentford     |   nan    |     nan      |       1.3       |     1.5      |       -0.2        |   nan    |     nan      |       1.3       |     1.1      |        0.2        |    2.0     |   1.3   |     0.7      |    1.0     |   0.9   |     0.1      |
# | 451 | 2024-2025 | 2024-10-19 |    Bournemouth    |  2–0  |      Arsenal      |   nan    |     nan      |       1.7       |     1.6      |        0.1        |   nan    |     nan      |       1.7       |     1.2      |        0.5        |    2.0     |   1.8   |     0.2      |    0.0     |   0.7   |     -0.7     |
# | 452 | 2024-2025 | 2024-10-19 |      Fulham       |  1–3  |    Aston Villa    |   nan    |     nan      |       1.5       |     1.5      |        0.0        |   nan    |     nan      |       1.8       |     1.2      |        0.6        |    1.0     |   1.8   |     -0.8     |    3.0     |   1.6   |     1.4      |
# | 453 | 2024-2025 | 2024-10-19 |   Ipswich Town    |  0–2  |      Everton      |   nan    |     nan      |       0.8       |     0.9      |       -0.1        |   nan    |     nan      |       1.1       |     1.2      |       -0.1        |    0.0     |   1.3   |     -1.3     |    2.0     |   1.7   |     0.3      |
# | 454 | 2024-2025 | 2024-10-19 |    Southampton    |  2–3  |  Leicester City   |   nan    |     nan      |       0.9       |     1.6      |       -0.7        |   nan    |     nan      |       2.1       |     1.5      |        0.6        |    2.0     |   2.1   |     -0.1     |    3.0     |   3.1   |     -0.1     |
# | 455 | 2024-2025 | 2024-10-19 |     Tottenham     |  4–1  |     West Ham      |   nan    |     nan      |       2.4       |     2.1      |        0.3        |   nan    |     nan      |       1.3       |     1.0      |        0.3        |    4.0     |   1.9   |     2.1      |    1.0     |   0.8   |     0.2      |
# | 456 | 2024-2025 | 2024-10-19 | Newcastle United  |  0–1  |     Brighton      |   nan    |     nan      |       1.7       |     2.0      |       -0.3        |   nan    |     nan      |       1.3       |     1.2      |        0.1        |    0.0     |   2.0   |     -2.0     |    1.0     |   1.1   |     -0.1     |
# | 457 | 2024-2025 | 2024-10-20 |      Wolves       |  1–2  |  Manchester City  |   nan    |     nan      |       1.2       |     1.1      |        0.1        |   nan    |     nan      |       2.3       |     1.8      |        0.5        |    1.0     |   0.8   |     0.2      |    2.0     |   1.6   |     0.4      |
# | 458 | 2024-2025 | 2024-10-20 |     Liverpool     |  2–1  |      Chelsea      |   nan    |     nan      |       2.1       |     2.4      |       -0.3        |   nan    |     nan      |       2.2       |     1.4      |        0.8        |    2.0     |   1.9   |     0.1      |    1.0     |   1.0   |     0.0      |
# | 459 | 2024-2025 | 2024-10-21 | Nottingham Forest |  1–0  |  Crystal Palace   |   nan    |     nan      |       1.1       |     1.4      |       -0.3        |   nan    |     nan      |       0.9       |     1.1      |       -0.2        |    1.0     |   1.7   |     -0.7     |    0.0     |   1.0   |     -1.0     |
# | 460 | 2024-2025 | 2024-10-25 |  Leicester City   |  1–3  | Nottingham Forest |   nan    |     nan      |       1.0       |     0.7      |        0.3        |   nan    |     nan      |       1.6       |     1.4      |        0.2        |    1.0     |   0.8   |     0.2      |    3.0     |   1.7   |     1.3      |
# | 461 | 2024-2025 | 2024-10-26 |      Everton      |  1–1  |      Fulham       |   nan    |     nan      |       1.1       |     1.1      |        0.0        |   nan    |     nan      |       1.3       |     1.4      |       -0.1        |    1.0     |   0.8   |     0.2      |    1.0     |   1.2   |     -0.2     |
# | 462 | 2024-2025 | 2024-10-26 |    Aston Villa    |  1–1  |    Bournemouth    |   nan    |     nan      |       1.7       |     1.6      |        0.1        |   nan    |     nan      |       1.0       |     1.4      |       -0.4        |    1.0     |   1.8   |     -0.8     |    1.0     |   0.3   |     0.7      |
# | 463 | 2024-2025 | 2024-10-26 |     Brighton      |  2–2  |      Wolves       |   nan    |     nan      |       1.6       |     1.5      |        0.1        |   nan    |     nan      |       1.4       |     0.9      |        0.5        |    2.0     |   1.3   |     0.7      |    2.0     |   1.3   |     0.7      |
# | 464 | 2024-2025 | 2024-10-26 |     Brentford     |  4–3  |   Ipswich Town    |   nan    |     nan      |       2.5       |     2.3      |        0.2        |   nan    |     nan      |       1.4       |     0.9      |        0.5        |    4.0     |   4.0   |     0.0      |    3.0     |   1.3   |     1.7      |
# | 465 | 2024-2025 | 2024-10-26 |  Manchester City  |  1–0  |    Southampton    |   nan    |     nan      |       2.5       |     2.5      |        0.0        |   nan    |     nan      |       0.6       |     0.8      |       -0.2        |    1.0     |   2.9   |     -1.9     |    0.0     |   0.2   |     -0.2     |
# | 466 | 2024-2025 | 2024-10-27 |      Chelsea      |  2–1  | Newcastle United  |   nan    |     nan      |       2.2       |     2.4      |       -0.2        |   nan    |     nan      |       1.4       |     1.8      |       -0.4        |    2.0     |   1.6   |     0.4      |    1.0     |   1.8   |     -0.8     |
# | 467 | 2024-2025 | 2024-10-27 |     West Ham      |  2–1  | Manchester United |   nan    |     nan      |       1.8       |     2.0      |       -0.2        |   nan    |     nan      |       1.1       |     1.5      |       -0.4        |    2.0     |   2.8   |     -0.8     |    1.0     |   2.3   |     -1.3     |
# | 468 | 2024-2025 | 2024-10-27 |  Crystal Palace   |  1–0  |     Tottenham     |   nan    |     nan      |       1.5       |     1.3      |        0.2        |   nan    |     nan      |       1.4       |     1.7      |       -0.3        |    1.0     |   0.8   |     0.2      |    0.0     |   0.7   |     -0.7     |
# | 469 | 2024-2025 | 2024-10-27 |      Arsenal      |  2–2  |     Liverpool     |   nan    |     nan      |       2.5       |     2.3      |        0.2        |   nan    |     nan      |       2.0       |     1.7      |        0.3        |    2.0     |   0.9   |     1.1      |    2.0     |   0.8   |     1.2      |
# | 470 | 2024-2025 | 2024-11-02 |    Bournemouth    |  2–1  |  Manchester City  |   nan    |     nan      |       1.8       |     1.7      |        0.1        |   nan    |     nan      |       2.0       |     1.8      |        0.2        |    2.0     |   2.0   |     0.0      |    1.0     |   1.6   |     -0.6     |
# | 471 | 2024-2025 | 2024-11-02 |   Ipswich Town    |  1–1  |  Leicester City   |   nan    |     nan      |       0.8       |     1.0      |       -0.2        |   nan    |     nan      |       1.8       |     1.5      |        0.3        |    1.0     |   1.0   |     0.0      |    1.0     |   1.5   |     -0.5     |
# | 472 | 2024-2025 | 2024-11-02 |      Wolves       |  2–2  |  Crystal Palace   |   nan    |     nan      |       1.3       |     1.2      |        0.1        |   nan    |     nan      |       1.1       |     1.3      |       -0.2        |    2.0     |   1.5   |     0.5      |    2.0     |   2.4   |     -0.4     |
# | 473 | 2024-2025 | 2024-11-02 |     Liverpool     |  2–1  |     Brighton      |   nan    |     nan      |       2.1       |     2.3      |       -0.2        |   nan    |     nan      |       1.2       |     1.2      |        0.0        |    2.0     |   1.6   |     0.4      |    1.0     |   1.0   |     0.0      |
# | 474 | 2024-2025 | 2024-11-02 | Newcastle United  |  1–0  |      Arsenal      |   nan    |     nan      |       1.6       |     1.7      |       -0.1        |   nan    |     nan      |       1.4       |     1.1      |        0.3        |    1.0     |   0.5   |     0.5      |    0.0     |   1.1   |     -1.1     |
# | 475 | 2024-2025 | 2024-11-02 |    Southampton    |  1–0  |      Everton      |   nan    |     nan      |       0.9       |     1.3      |       -0.4        |   nan    |     nan      |       0.9       |     1.3      |       -0.4        |    1.0     |   0.7   |     0.3      |    0.0     |   1.6   |     -1.6     |
# | 476 | 2024-2025 | 2024-11-02 | Nottingham Forest |  3–0  |     West Ham      |   nan    |     nan      |       1.4       |     1.5      |       -0.1        |   nan    |     nan      |       1.0       |     0.9      |        0.1        |    3.0     |   2.2   |     0.8      |    0.0     |   0.1   |     -0.1     |
# | 477 | 2024-2025 | 2024-11-03 |     Tottenham     |  4–1  |    Aston Villa    |   nan    |     nan      |       2.7       |     2.2      |        0.5        |   nan    |     nan      |       1.7       |     1.3      |        0.4        |    4.0     |   2.4   |     1.6      |    1.0     |   1.8   |     -0.8     |
# | 478 | 2024-2025 | 2024-11-03 | Manchester United |  1–1  |      Chelsea      |   nan    |     nan      |       1.2       |     1.6      |       -0.4        |   nan    |     nan      |       2.0       |     1.4      |        0.6        |    1.0     |   2.0   |     -1.0     |    1.0     |   1.1   |     -0.1     |
# | 479 | 2024-2025 | 2024-11-04 |      Fulham       |  2–1  |     Brentford     |   nan    |     nan      |       1.6       |     1.5      |        0.1        |   nan    |     nan      |       1.2       |     1.0      |        0.2        |    2.0     |   1.3   |     0.7      |    1.0     |   0.6   |     0.4      |
# | 480 | 2024-2025 | 2024-11-09 |     Liverpool     |  2–0  |    Aston Villa    |   nan    |     nan      |       2.1       |     2.2      |       -0.1        |   nan    |     nan      |       1.4       |     1.3      |        0.1        |    2.0     |   2.0   |     0.0      |    0.0     |   1.2   |     -1.2     |
# | 481 | 2024-2025 | 2024-11-09 |     Brighton      |  2–1  |  Manchester City  |   nan    |     nan      |       1.6       |     1.6      |        0.0        |   nan    |     nan      |       1.8       |     1.8      |        0.0        |    2.0     |   2.3   |     -0.3     |    1.0     |   2.1   |     -1.1     |
# | 482 | 2024-2025 | 2024-11-09 |     Brentford     |  3–2  |    Bournemouth    |   nan    |     nan      |       2.6       |     2.2      |        0.4        |   nan    |     nan      |       1.2       |     1.6      |       -0.4        |    3.0     |   1.5   |     1.5      |    2.0     |   2.6   |     -0.6     |
# | 483 | 2024-2025 | 2024-11-09 |  Crystal Palace   |  0–2  |      Fulham       |   nan    |     nan      |       1.2       |     1.4      |       -0.2        |   nan    |     nan      |       1.5       |     1.5      |        0.0        |    0.0     |   1.5   |     -1.5     |    2.0     |   1.8   |     0.2      |
# | 484 | 2024-2025 | 2024-11-09 |      Wolves       |  2–0  |    Southampton    |   nan    |     nan      |       1.4       |     1.2      |        0.2        |   nan    |     nan      |       0.4       |     0.7      |       -0.3        |    2.0     |   1.3   |     0.7      |    0.0     |   0.6   |     -0.6     |
# | 485 | 2024-2025 | 2024-11-09 |     West Ham      |  0–0  |      Everton      |   nan    |     nan      |       1.4       |     1.8      |       -0.4        |   nan    |     nan      |       0.7       |     1.2      |       -0.5        |    0.0     |   0.8   |     -0.8     |    0.0     |   1.1   |     -1.1     |
# | 486 | 2024-2025 | 2024-11-10 |     Tottenham     |  1–2  |   Ipswich Town    |   nan    |     nan      |       2.4       |     2.1      |        0.3        |   nan    |     nan      |       1.6       |     1.1      |        0.5        |    1.0     |   1.5   |     -0.5     |    2.0     |   1.6   |     0.4      |
# | 487 | 2024-2025 | 2024-11-10 |      Chelsea      |  1–1  |      Arsenal      |   nan    |     nan      |       2.0       |     2.2      |       -0.2        |   nan    |     nan      |       1.3       |     1.2      |        0.1        |    1.0     |   1.5   |     -0.5     |    1.0     |   1.5   |     -0.5     |
# | 488 | 2024-2025 | 2024-11-10 | Manchester United |  3–0  |  Leicester City   |   nan    |     nan      |       1.6       |     1.5      |        0.1        |   nan    |     nan      |       1.3       |     1.3      |        0.0        |    3.0     |   0.8   |     2.2      |    0.0     |   0.6   |     -0.6     |
# | 489 | 2024-2025 | 2024-11-10 | Nottingham Forest |  1–3  | Newcastle United  |   nan    |     nan      |       1.3       |     1.3      |        0.0        |   nan    |     nan      |       1.7       |     1.8      |       -0.1        |    1.0     |   0.6   |     0.4      |    3.0     |   1.6   |     1.4      |
# | 490 | 2024-2025 | 2024-11-23 |  Leicester City   |  1–2  |      Chelsea      |   nan    |     nan      |       1.0       |     0.8      |        0.2        |   nan    |     nan      |       2.0       |     1.6      |        0.4        |    1.0     |   1.1   |     -0.1     |    2.0     |   2.7   |     -0.7     |
# | 491 | 2024-2025 | 2024-11-23 |      Arsenal      |  3–0  | Nottingham Forest |   nan    |     nan      |       2.6       |     2.1      |        0.5        |   nan    |     nan      |       1.3       |     1.2      |        0.1        |    3.0     |   1.2   |     1.8      |    0.0     |   0.3   |     -0.3     |
# | 492 | 2024-2025 | 2024-11-23 |    Bournemouth    |  1–2  |     Brighton      |   nan    |     nan      |       1.6       |     1.7      |       -0.1        |   nan    |     nan      |       1.4       |     1.1      |        0.3        |    1.0     |   1.6   |     -0.6     |    2.0     |   0.9   |     1.1      |
# | 493 | 2024-2025 | 2024-11-23 |    Aston Villa    |  2–2  |  Crystal Palace   |   nan    |     nan      |       1.8       |     1.9      |       -0.1        |   nan    |     nan      |       1.3       |     1.3      |        0.0        |    2.0     |   3.0   |     -1.0     |    2.0     |   1.3   |     0.7      |
# | 494 | 2024-2025 | 2024-11-23 |      Everton      |  0–0  |     Brentford     |   nan    |     nan      |       0.9       |     1.1      |       -0.2        |   nan    |     nan      |       1.0       |     1.0      |        0.0        |    0.0     |   1.2   |     -1.2     |    0.0     |   1.1   |     -1.1     |
# | 495 | 2024-2025 | 2024-11-23 |      Fulham       |  1–4  |      Wolves       |   nan    |     nan      |       1.5       |     1.4      |        0.1        |   nan    |     nan      |       1.9       |     1.0      |        0.9        |    1.0     |   1.0   |     0.0      |    4.0     |   1.3   |     2.7      |
# | 496 | 2024-2025 | 2024-11-23 |  Manchester City  |  0–4  |     Tottenham     |   nan    |     nan      |       2.1       |     2.4      |       -0.3        |   nan    |     nan      |       1.9       |     1.8      |        0.1        |    0.0     |   2.1   |     -2.1     |    4.0     |   2.5   |     1.5      |
# | 497 | 2024-2025 | 2024-11-24 |    Southampton    |  2–3  |     Liverpool     |   nan    |     nan      |       1.2       |     1.3      |       -0.1        |   nan    |     nan      |       2.2       |     2.0      |        0.2        |    2.0     |   1.3   |     0.7      |    3.0     |   3.1   |     -0.1     |
# | 498 | 2024-2025 | 2024-11-24 |   Ipswich Town    |  1–1  | Manchester United |   nan    |     nan      |       0.9       |     1.1      |       -0.2        |   nan    |     nan      |       1.1       |     1.4      |       -0.3        |    1.0     |   1.6   |     -0.6     |    1.0     |   0.8   |     0.2      |
# | 499 | 2024-2025 | 2024-11-25 | Newcastle United  |  0–2  |     West Ham      |   nan    |     nan      |       1.3       |     1.7      |       -0.4        |   nan    |     nan      |       1.2       |     0.9      |        0.3        |    0.0     |   1.6   |     -1.6     |    2.0     |   0.9   |     1.1      |
# | 500 | 2024-2025 | 2024-11-29 |     Brighton      |  1–1  |    Southampton    |   nan    |     nan      |       1.5       |     1.6      |       -0.1        |   nan    |     nan      |       0.6       |     0.8      |       -0.2        |    1.0     |   1.7   |     -0.7     |    1.0     |   1.0   |     0.0      |
# | 501 | 2024-2025 | 2024-11-30 |     Brentford     |  4–1  |  Leicester City   |   nan    |     nan      |       2.9       |     2.2      |        0.7        |   nan    |     nan      |       1.3       |     1.2      |        0.1        |    4.0     |   2.4   |     1.6      |    1.0     |   1.1   |     -0.1     |
# | 502 | 2024-2025 | 2024-11-30 |     West Ham      |  2–5  |      Arsenal      |   nan    |     nan      |       1.5       |     1.7      |       -0.2        |   nan    |     nan      |       2.0       |     1.6      |        0.4        |    2.0     |   1.5   |     0.5      |    5.0     |   3.5   |     1.5      |
# | 503 | 2024-2025 | 2024-11-30 |      Wolves       |  2–4  |    Bournemouth    |   nan    |     nan      |       1.5       |     1.1      |        0.4        |   nan    |     nan      |       1.7       |     1.9      |       -0.2        |    2.0     |   0.5   |     1.5      |    4.0     |   3.3   |     0.7      |
# | 504 | 2024-2025 | 2024-11-30 |  Crystal Palace   |  1–1  | Newcastle United  |   nan    |     nan      |       1.2       |     1.4      |       -0.2        |   nan    |     nan      |       1.6       |     1.4      |        0.2        |    1.0     |   1.7   |     -0.7     |    1.0     |   0.0   |     1.0      |
# | 505 | 2024-2025 | 2024-11-30 | Nottingham Forest |  1–0  |   Ipswich Town    |   nan    |     nan      |       1.3       |     1.4      |       -0.1        |   nan    |     nan      |       1.2       |     1.0      |        0.2        |    1.0     |   1.6   |     -0.6     |    0.0     |   0.6   |     -0.6     |
# | 506 | 2024-2025 | 2024-12-01 | Manchester United |  4–0  |      Everton      |   nan    |     nan      |       2.0       |     1.4      |        0.6        |   nan    |     nan      |       0.6       |     1.1      |       -0.5        |    4.0     |   1.1   |     2.9      |    0.0     |   0.6   |     -0.6     |
# | 507 | 2024-2025 | 2024-12-01 |     Liverpool     |  2–0  |  Manchester City  |   nan    |     nan      |       2.0       |     2.4      |       -0.4        |   nan    |     nan      |       1.5       |     1.6      |       -0.1        |    2.0     |   3.4   |     -1.4     |    0.0     |   0.8   |     -0.8     |
# | 508 | 2024-2025 | 2024-12-01 |      Chelsea      |  3–0  |    Aston Villa    |   nan    |     nan      |       2.2       |     2.1      |        0.1        |   nan    |     nan      |       1.1       |     1.3      |       -0.2        |    3.0     |   1.6   |     1.4      |    0.0     |   1.2   |     -1.2     |
# | 509 | 2024-2025 | 2024-12-01 |     Tottenham     |  1–1  |      Fulham       |   nan    |     nan      |       2.1       |     1.8      |        0.3        |   nan    |     nan      |       1.4       |     1.5      |       -0.1        |    1.0     |   0.8   |     0.2      |    1.0     |   1.5   |     -0.5     |
# | 510 | 2024-2025 | 2024-12-03 |   Ipswich Town    |  0–1  |  Crystal Palace   |   nan    |     nan      |       0.7       |     1.0      |       -0.3        |   nan    |     nan      |       1.2       |     1.4      |       -0.2        |    0.0     |   0.5   |     -0.5     |    1.0     |   1.6   |     -0.6     |
# | 511 | 2024-2025 | 2024-12-03 |  Leicester City   |  3–1  |     West Ham      |   nan    |     nan      |       1.5       |     1.0      |        0.5        |   nan    |     nan      |       1.2       |     1.3      |       -0.1        |    3.0     |   1.7   |     1.3      |    1.0     |   3.0   |     -2.0     |
# | 512 | 2024-2025 | 2024-12-04 |      Everton      |  4–0  |      Wolves       |   nan    |     nan      |       1.5       |     1.1      |        0.4        |   nan    |     nan      |       1.5       |     0.9      |        0.6        |    4.0     |   1.0   |     3.0      |    0.0     |   0.8   |     -0.8     |
# | 513 | 2024-2025 | 2024-12-04 |  Manchester City  |  3–0  | Nottingham Forest |   nan    |     nan      |       2.2       |     2.4      |       -0.2        |   nan    |     nan      |       1.1       |     1.1      |        0.0        |    3.0     |   2.4   |     0.6      |    0.0     |   1.0   |     -1.0     |
# | 514 | 2024-2025 | 2024-12-04 |    Southampton    |  1–5  |      Chelsea      |   nan    |     nan      |       1.2       |     1.4      |       -0.2        |   nan    |     nan      |       2.5       |     2.3      |        0.2        |    1.0     |   1.6   |     -0.6     |    5.0     |   5.2   |     -0.2     |
# | 515 | 2024-2025 | 2024-12-04 |      Arsenal      |  2–0  | Manchester United |   nan    |     nan      |       2.5       |     2.1      |        0.4        |   nan    |     nan      |       0.9       |     1.2      |       -0.3        |    2.0     |   2.1   |     -0.1     |    0.0     |   0.2   |     -0.2     |
# | 516 | 2024-2025 | 2024-12-04 |    Aston Villa    |  3–1  |     Brentford     |   nan    |     nan      |       2.0       |     2.0      |        0.0        |   nan    |     nan      |       1.0       |     1.0      |        0.0        |    3.0     |   2.4   |     0.6      |    1.0     |   0.9   |     0.1      |
# | 517 | 2024-2025 | 2024-12-04 | Newcastle United  |  3–3  |     Liverpool     |   nan    |     nan      |       1.6       |     1.8      |       -0.2        |   nan    |     nan      |       2.3       |     2.0      |        0.3        |    3.0     |   2.1   |     0.9      |    3.0     |   1.9   |     1.1      |
# | 518 | 2024-2025 | 2024-12-05 |      Fulham       |  3–1  |     Brighton      |   nan    |     nan      |       1.8       |     1.4      |        0.4        |   nan    |     nan      |       1.3       |     1.2      |        0.1        |    3.0     |   1.1   |     1.9      |    1.0     |   1.4   |     -0.4     |
# | 519 | 2024-2025 | 2024-12-05 |    Bournemouth    |  1–0  |     Tottenham     |   nan    |     nan      |       1.5       |     2.0      |       -0.5        |   nan    |     nan      |       1.6       |     1.7      |       -0.1        |    1.0     |   3.5   |     -2.5     |    0.0     |   0.9   |     -0.9     |
# | 520 | 2024-2025 | 2024-12-07 | Manchester United |  2–3  | Nottingham Forest |   nan    |     nan      |       2.0       |     1.4      |        0.6        |   nan    |     nan      |       1.4       |     1.1      |        0.3        |    2.0     |   1.6   |     0.4      |    3.0     |   0.8   |     2.2      |
# | 521 | 2024-2025 | 2024-12-07 |    Aston Villa    |  1–0  |    Southampton    |   nan    |     nan      |       1.8       |     2.0      |       -0.2        |   nan    |     nan      |       0.4       |     0.7      |       -0.3        |    1.0     |   2.3   |     -1.3     |    0.0     |   0.3   |     -0.3     |
# | 522 | 2024-2025 | 2024-12-07 |  Crystal Palace   |  2–2  |  Manchester City  |   nan    |     nan      |       1.3       |     1.4      |       -0.1        |   nan    |     nan      |       1.6       |     1.6      |        0.0        |    2.0     |   1.3   |     0.7      |    2.0     |   1.4   |     0.6      |
# | 523 | 2024-2025 | 2024-12-07 |     Brentford     |  4–2  | Newcastle United  |   nan    |     nan      |       3.1       |     2.0      |        1.1        |   nan    |     nan      |       1.6       |     1.4      |        0.2        |    4.0     |   1.2   |     2.8      |    2.0     |   1.5   |     0.5      |
# | 524 | 2024-2025 | 2024-12-08 |      Fulham       |  1–1  |      Arsenal      |   nan    |     nan      |       1.6       |     1.1      |        0.5        |   nan    |     nan      |       1.8       |     1.7      |        0.1        |    1.0     |   0.2   |     0.8      |    1.0     |   1.8   |     -0.8     |
# | 525 | 2024-2025 | 2024-12-08 |     Tottenham     |  3–4  |      Chelsea      |   nan    |     nan      |       2.3       |     2.0      |        0.3        |   nan    |     nan      |       2.8       |     2.4      |        0.4        |    3.0     |   2.8   |     0.2      |    4.0     |   2.8   |     1.2      |
# | 526 | 2024-2025 | 2024-12-08 |   Ipswich Town    |  1–2  |    Bournemouth    |   nan    |     nan      |       0.7       |     1.0      |       -0.3        |   nan    |     nan      |       1.7       |     2.2      |       -0.5        |    1.0     |   1.3   |     -0.3     |    2.0     |   3.2   |     -1.2     |
# | 527 | 2024-2025 | 2024-12-08 |  Leicester City   |  2–2  |     Brighton      |   nan    |     nan      |       1.6       |     1.1      |        0.5        |   nan    |     nan      |       1.4       |     1.2      |        0.2        |    2.0     |   1.3   |     0.7      |    2.0     |   1.5   |     0.5      |
# | 528 | 2024-2025 | 2024-12-09 |     West Ham      |  2–1  |      Wolves       |   nan    |     nan      |       1.6       |     1.6      |        0.0        |   nan    |     nan      |       1.4       |     1.0      |        0.4        |    2.0     |   1.0   |     1.0      |    1.0     |   1.4   |     -0.4     |
# ...
# | 711 | 2024-2025 | 2025-04-26 |     Brighton      |  nan  |     West Ham      |   nan    |     nan      |       1.5       |     1.5      |        0.0        |   nan    |     nan      |       1.0       |     1.2      |       -0.2        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 712 | 2024-2025 | 2025-04-26 |      Chelsea      |  nan  |      Everton      |   nan    |     nan      |       2.2       |     2.1      |        0.1        |   nan    |     nan      |       0.9       |     1.0      |       -0.1        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 713 | 2024-2025 | 2025-04-26 |    Southampton    |  nan  |      Fulham       |   nan    |     nan      |       0.7       |     0.9      |       -0.2        |   nan    |     nan      |       1.7       |     1.5      |        0.2        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 714 | 2024-2025 | 2025-04-26 | Newcastle United  |  nan  |   Ipswich Town    |   nan    |     nan      |       2.3       |     2.0      |        0.3        |   nan    |     nan      |       1.1       |     1.0      |        0.1        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 715 | 2024-2025 | 2025-04-26 | Nottingham Forest |  nan  |     Brentford     |   nan    |     nan      |       1.9       |     1.3      |        0.6        |   nan    |     nan      |       2.0       |     1.5      |        0.5        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 716 | 2024-2025 | 2025-04-26 |      Wolves       |  nan  |  Leicester City   |   nan    |     nan      |       1.1       |     1.1      |        0.0        |   nan    |     nan      |       0.6       |     0.6      |        0.0        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 717 | 2024-2025 | 2025-04-27 |    Bournemouth    |  nan  | Manchester United |   nan    |     nan      |       1.2       |     1.6      |       -0.4        |   nan    |     nan      |       1.1       |     1.0      |        0.1        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 718 | 2024-2025 | 2025-04-27 |     Liverpool     |  nan  |     Tottenham     |   nan    |     nan      |       2.5       |     2.4      |        0.1        |   nan    |     nan      |       2.2       |     1.4      |        0.8        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 719 | 2024-2025 | 2025-04-28 |  Manchester City  |  nan  |    Aston Villa    |   nan    |     nan      |       2.1       |     1.8      |        0.3        |   nan    |     nan      |       0.9       |     0.9      |        0.0        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 720 | 2024-2025 | 2025-05-03 |  Leicester City   |  nan  |    Southampton    |   nan    |     nan      |       0.4       |     0.8      |       -0.4        |   nan    |     nan      |       0.9       |     0.7      |        0.2        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 721 | 2024-2025 | 2025-05-03 |     Brighton      |  nan  | Newcastle United  |   nan    |     nan      |       1.5       |     1.5      |        0.0        |   nan    |     nan      |       1.4       |     1.4      |        0.0        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 722 | 2024-2025 | 2025-05-03 |    Aston Villa    |  nan  |      Fulham       |   nan    |     nan      |       1.7       |     1.7      |        0.0        |   nan    |     nan      |       1.7       |     1.5      |        0.2        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 723 | 2024-2025 | 2025-05-03 |      Everton      |  nan  |   Ipswich Town    |   nan    |     nan      |       1.7       |     1.3      |        0.4        |   nan    |     nan      |       1.1       |     1.0      |        0.1        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 724 | 2024-2025 | 2025-05-03 |      Arsenal      |  nan  |    Bournemouth    |   nan    |     nan      |       2.0       |     1.5      |        0.5        |   nan    |     nan      |       2.2       |     1.8      |        0.4        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 725 | 2024-2025 | 2025-05-03 |  Crystal Palace   |  nan  | Nottingham Forest |   nan    |     nan      |       1.6       |     2.2      |       -0.6        |   nan    |     nan      |       2.1       |     1.2      |        0.9        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 726 | 2024-2025 | 2025-05-03 |     West Ham      |  nan  |     Tottenham     |   nan    |     nan      |       1.0       |     1.0      |        0.0        |   nan    |     nan      |       2.2       |     1.4      |        0.8        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 727 | 2024-2025 | 2025-05-03 |  Manchester City  |  nan  |      Wolves       |   nan    |     nan      |       2.1       |     1.8      |        0.3        |   nan    |     nan      |       1.4       |     1.1      |        0.3        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 728 | 2024-2025 | 2025-05-03 |     Brentford     |  nan  | Manchester United |   nan    |     nan      |       1.1       |     1.4      |       -0.3        |   nan    |     nan      |       1.1       |     1.0      |        0.1        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 729 | 2024-2025 | 2025-05-03 |      Chelsea      |  nan  |     Liverpool     |   nan    |     nan      |       2.2       |     2.1      |        0.1        |   nan    |     nan      |       2.3       |     2.0      |        0.3        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 730 | 2024-2025 | 2025-05-10 |      Wolves       |  nan  |     Brighton      |   nan    |     nan      |       1.1       |     1.1      |        0.0        |   nan    |     nan      |       2.0       |     1.8      |        0.2        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 731 | 2024-2025 | 2025-05-10 |   Ipswich Town    |  nan  |     Brentford     |   nan    |     nan      |       1.0       |     0.9      |        0.1        |   nan    |     nan      |       2.0       |     1.5      |        0.5        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 732 | 2024-2025 | 2025-05-10 |    Bournemouth    |  nan  |    Aston Villa    |   nan    |     nan      |       1.2       |     1.6      |       -0.4        |   nan    |     nan      |       0.9       |     0.9      |        0.0        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 733 | 2024-2025 | 2025-05-10 | Manchester United |  nan  |     West Ham      |   nan    |     nan      |       1.5       |     1.5      |        0.0        |   nan    |     nan      |       1.0       |     1.2      |       -0.2        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 734 | 2024-2025 | 2025-05-10 |      Fulham       |  nan  |      Everton      |   nan    |     nan      |       1.1       |     1.1      |        0.0        |   nan    |     nan      |       0.9       |     1.0      |       -0.1        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 735 | 2024-2025 | 2025-05-10 | Newcastle United  |  nan  |      Chelsea      |   nan    |     nan      |       2.3       |     2.0      |        0.3        |   nan    |     nan      |       1.2       |     1.8      |       -0.6        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 736 | 2024-2025 | 2025-05-10 |     Tottenham     |  nan  |  Crystal Palace   |   nan    |     nan      |       1.5       |     1.6      |       -0.1        |   nan    |     nan      |       1.7       |     1.5      |        0.2        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 737 | 2024-2025 | 2025-05-10 |    Southampton    |  nan  |  Manchester City  |   nan    |     nan      |       0.7       |     0.9      |       -0.2        |   nan    |     nan      |       1.6       |     1.6      |        0.0        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 738 | 2024-2025 | 2025-05-10 | Nottingham Forest |  nan  |  Leicester City   |   nan    |     nan      |       1.9       |     1.3      |        0.6        |   nan    |     nan      |       0.6       |     0.6      |        0.0        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 739 | 2024-2025 | 2025-05-10 |     Liverpool     |  nan  |      Arsenal      |   nan    |     nan      |       2.5       |     2.4      |        0.1        |   nan    |     nan      |       1.5       |     1.5      |        0.0        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 740 | 2024-2025 | 2025-05-18 |     Brentford     |  nan  |      Fulham       |   nan    |     nan      |       1.1       |     1.4      |       -0.3        |   nan    |     nan      |       1.7       |     1.5      |        0.2        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 741 | 2024-2025 | 2025-05-18 |      Arsenal      |  nan  | Newcastle United  |   nan    |     nan      |       2.0       |     1.5      |        0.5        |   nan    |     nan      |       1.4       |     1.4      |        0.0        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 742 | 2024-2025 | 2025-05-18 |     Brighton      |  nan  |     Liverpool     |   nan    |     nan      |       1.5       |     1.5      |        0.0        |   nan    |     nan      |       2.3       |     2.0      |        0.3        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 743 | 2024-2025 | 2025-05-18 |  Leicester City   |  nan  |   Ipswich Town    |   nan    |     nan      |       0.4       |     0.8      |       -0.4        |   nan    |     nan      |       1.1       |     1.0      |        0.1        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 744 | 2024-2025 | 2025-05-18 |     West Ham      |  nan  | Nottingham Forest |   nan    |     nan      |       1.0       |     1.0      |        0.0        |   nan    |     nan      |       2.1       |     1.2      |        0.9        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 745 | 2024-2025 | 2025-05-18 |      Everton      |  nan  |    Southampton    |   nan    |     nan      |       1.7       |     1.3      |        0.4        |   nan    |     nan      |       0.9       |     0.7      |        0.2        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 746 | 2024-2025 | 2025-05-18 |    Aston Villa    |  nan  |     Tottenham     |   nan    |     nan      |       1.7       |     1.7      |        0.0        |   nan    |     nan      |       2.2       |     1.4      |        0.8        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 747 | 2024-2025 | 2025-05-18 |      Chelsea      |  nan  | Manchester United |   nan    |     nan      |       2.2       |     2.1      |        0.1        |   nan    |     nan      |       1.1       |     1.0      |        0.1        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 748 | 2024-2025 | 2025-05-18 |  Manchester City  |  nan  |    Bournemouth    |   nan    |     nan      |       2.1       |     1.8      |        0.3        |   nan    |     nan      |       2.2       |     1.8      |        0.4        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 749 | 2024-2025 | 2025-05-18 |  Crystal Palace   |  nan  |      Wolves       |   nan    |     nan      |       1.6       |     2.2      |       -0.6        |   nan    |     nan      |       1.4       |     1.1      |        0.3        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 750 | 2024-2025 | 2025-05-25 | Manchester United |  nan  |    Aston Villa    |   nan    |     nan      |       1.5       |     1.5      |        0.0        |   nan    |     nan      |       0.9       |     0.9      |        0.0        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 751 | 2024-2025 | 2025-05-25 |    Southampton    |  nan  |      Arsenal      |   nan    |     nan      |       0.7       |     0.9      |       -0.2        |   nan    |     nan      |       1.5       |     1.5      |        0.0        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 752 | 2024-2025 | 2025-05-25 |     Liverpool     |  nan  |  Crystal Palace   |   nan    |     nan      |       2.5       |     2.4      |        0.1        |   nan    |     nan      |       1.7       |     1.5      |        0.2        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 753 | 2024-2025 | 2025-05-25 |   Ipswich Town    |  nan  |     West Ham      |   nan    |     nan      |       1.0       |     0.9      |        0.1        |   nan    |     nan      |       1.0       |     1.2      |       -0.2        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 754 | 2024-2025 | 2025-05-25 |    Bournemouth    |  nan  |  Leicester City   |   nan    |     nan      |       1.2       |     1.6      |       -0.4        |   nan    |     nan      |       0.6       |     0.6      |        0.0        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 755 | 2024-2025 | 2025-05-25 | Newcastle United  |  nan  |      Everton      |   nan    |     nan      |       2.3       |     2.0      |        0.3        |   nan    |     nan      |       0.9       |     1.0      |       -0.1        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 756 | 2024-2025 | 2025-05-25 |      Fulham       |  nan  |  Manchester City  |   nan    |     nan      |       1.1       |     1.1      |        0.0        |   nan    |     nan      |       1.6       |     1.6      |        0.0        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 757 | 2024-2025 | 2025-05-25 | Nottingham Forest |  nan  |      Chelsea      |   nan    |     nan      |       1.9       |     1.3      |        0.6        |   nan    |     nan      |       1.2       |     1.8      |       -0.6        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 758 | 2024-2025 | 2025-05-25 |      Wolves       |  nan  |     Brentford     |   nan    |     nan      |       1.1       |     1.1      |        0.0        |   nan    |     nan      |       2.0       |     1.5      |        0.5        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# | 759 | 2024-2025 | 2025-05-25 |     Tottenham     |  nan  |     Brighton      |   nan    |     nan      |       1.5       |     1.6      |       -0.1        |   nan    |     nan      |       2.0       |     1.8      |        0.2        |    nan     |   nan   |     nan      |    nan     |   nan   |     nan      |
# +-----+-----------+------------+-------------------+-------+-------------------+----------+--------------+-----------------+--------------+-------------------+----------+--------------+-----------------+--------------+-------------------+------------+---------+--------------+------------+---------+--------------+

# %%
with pd.option_context("display.max_rows", None):
  print(tabulate(matches[matches['season']=='2024-2025'].head(20), headers='keys', tablefmt='pretty'))
# Out:
# +----+------------+-------------------+-----+-------+------+-------------------+------------+------------+-----------+
# |    |    Date    |       Home        | xG  | Score | xG.1 |       Away        | score_home | score_away |  season   |
# +----+------------+-------------------+-----+-------+------+-------------------+------------+------------+-----------+
# | 0  | 2024-08-16 | Manchester United | 2.4 |  1–0  | 0.4  |      Fulham       |    1.0     |    0.0     | 2024-2025 |
# | 1  | 2024-08-17 |   Ipswich Town    | 0.5 |  0–2  | 2.6  |     Liverpool     |    0.0     |    2.0     | 2024-2025 |
# | 2  | 2024-08-17 | Newcastle United  | 0.3 |  1–0  | 1.8  |    Southampton    |    1.0     |    0.0     | 2024-2025 |
# | 3  | 2024-08-17 | Nottingham Forest | 1.3 |  1–1  | 1.2  |    Bournemouth    |    1.0     |    1.0     | 2024-2025 |
# | 4  | 2024-08-17 |      Everton      | 0.5 |  0–3  | 1.4  |     Brighton      |    0.0     |    3.0     | 2024-2025 |
# | 5  | 2024-08-17 |      Arsenal      | 1.2 |  2–0  | 0.5  |      Wolves       |    2.0     |    0.0     | 2024-2025 |
# | 6  | 2024-08-17 |     West Ham      | 2.3 |  1–2  | 2.0  |    Aston Villa    |    1.0     |    2.0     | 2024-2025 |
# | 8  | 2024-08-18 |      Chelsea      | 1.0 |  0–2  | 0.8  |  Manchester City  |    0.0     |    2.0     | 2024-2025 |
# | 7  | 2024-08-18 |     Brentford     | 1.6 |  2–1  | 1.2  |  Crystal Palace   |    2.0     |    1.0     | 2024-2025 |
# | 9  | 2024-08-19 |  Leicester City   | 1.0 |  1–1  | 1.2  |     Tottenham     |    1.0     |    1.0     | 2024-2025 |
# | 13 | 2024-08-24 |      Fulham       | 1.8 |  2–1  | 0.6  |  Leicester City   |    2.0     |    1.0     | 2024-2025 |
# | 14 | 2024-08-24 |  Crystal Palace   | 1.3 |  0–2  | 1.4  |     West Ham      |    0.0     |    2.0     | 2024-2025 |
# | 15 | 2024-08-24 |  Manchester City  | 3.3 |  4–1  | 0.3  |   Ipswich Town    |    4.0     |    1.0     | 2024-2025 |
# | 16 | 2024-08-24 |    Southampton    | 0.1 |  0–1  | 2.2  | Nottingham Forest |    0.0     |    1.0     | 2024-2025 |
# | 17 | 2024-08-24 |    Aston Villa    | 1.2 |  0–2  | 0.9  |      Arsenal      |    0.0     |    2.0     | 2024-2025 |
# | 12 | 2024-08-24 |     Tottenham     | 2.4 |  4–0  | 1.0  |      Everton      |    4.0     |    0.0     | 2024-2025 |
# | 11 | 2024-08-24 |     Brighton      | 2.1 |  2–1  | 1.4  | Manchester United |    2.0     |    1.0     | 2024-2025 |
# | 18 | 2024-08-25 |    Bournemouth    | 2.2 |  1–1  | 1.6  | Newcastle United  |    1.0     |    1.0     | 2024-2025 |
# | 19 | 2024-08-25 |      Wolves       | 1.9 |  2–6  | 1.6  |      Chelsea      |    2.0     |    6.0     | 2024-2025 |
# | 20 | 2024-08-25 |     Liverpool     | 2.5 |  2–0  | 0.5  |     Brentford     |    2.0     |    0.0     | 2024-2025 |
# +----+------------+-------------------+-----+-------+------+-------------------+------------+------------+-----------+

# %%
with pd.option_context("display.max_rows", None):
  print(tabulate(odds_df.head(20), headers='keys', tablefmt='pretty'))
# Out:
# +----+------------+-------------------+-------------------+-----------+-----------+-----------+--------------+--------------+----------+----------+
# |    |    Date    |       Home        |       Away        | odds_home | odds_draw | odds_away | odds_home_xG | odds_away_xG | home_CS% | away_CS% |
# +----+------------+-------------------+-------------------+-----------+-----------+-----------+--------------+--------------+----------+----------+
# | 0  | 2025-03-16 |      Arsenal      |      Chelsea      |    1.8    |    4.5    |    3.5    |     3.1      |     2.4      |   9.1    |   4.5    |
# | 1  | 2025-03-16 |      Fulham       |     Tottenham     |   1.95    |    3.6    |    3.6    |     3.1      |     2.5      |   8.2    |   4.5    |
# | 2  | 2025-03-16 |  Leicester City   | Manchester United |    4.2    |   1.83    |    3.6    |     2.7      |     2.8      |   6.1    |   6.7    |
# | 3  | 2025-04-01 |      Arsenal      |      Fulham       |   1.36    |    8.0    |    4.5    |     3.4      |     2.2      |   11.1   |   3.3    |
# | 4  | 2025-04-01 |      Wolves       |     West Ham      |    3.2    |   2.25    |    3.3    |     2.8      |     2.8      |   6.1    |   6.1    |
# | 5  | 2025-04-01 | Nottingham Forest | Manchester United |   2.88    |   2.25    |    3.6    |     2.9      |     2.7      |   6.7    |   5.5    |
# | 6  | 2025-04-02 |     Brighton      |    Aston Villa    |    3.3    |    2.0    |   3.75    |     2.8      |     2.7      |   6.7    |   6.1    |
# | 7  | 2025-04-02 |    Bournemouth    |   Ipswich Town    |   1.36    |    7.0    |   4.75    |     3.4      |     2.1      |   12.2   |   3.3    |
# | 8  | 2025-04-02 | Newcastle United  |     Brentford     |    4.4    |   1.62    |    4.5    |     2.8      |     2.8      |   6.1    |   6.1    |
# | 9  | 2025-04-02 |    Southampton    |  Crystal Palace   |   1.62    |    5.0    |    4.0    |     3.2      |     2.3      |   10.0   |   4.1    |
# | 10 | 2025-04-02 |  Manchester City  |  Leicester City   |   15.0    |   1.14    |    7.5    |     2.4      |     3.1      |   4.5    |   9.1    |
# | 11 | 2025-04-02 |     Liverpool     |      Everton      |   11.0    |   1.25    |    5.5    |     2.4      |     3.1      |   4.5    |   9.1    |
# | 12 | 2025-04-03 |      Chelsea      |     Tottenham     |   1.62    |    4.4    |    4.4    |     3.3      |     2.3      |   10.0   |   3.7    |
# | 13 | 2025-04-05 |      Everton      |      Arsenal      |   1.62    |    5.5    |   3.75    |     3.2      |     2.3      |   10.0   |   4.1    |
# | 14 | 2025-04-05 |     West Ham      |    Bournemouth    |    2.2    |    3.0    |    3.4    |     3.0      |     2.5      |   8.2    |   5.0    |
# | 15 | 2025-04-05 |  Crystal Palace   |     Brighton      |   2.62    |   2.62    |    3.3    |     2.9      |     2.7      |   6.7    |   5.5    |
# | 16 | 2025-04-05 |   Ipswich Town    |      Wolves       |   2.75    |    2.4    |    3.4    |     2.9      |     2.7      |   6.7    |   5.5    |
# | 17 | 2025-04-05 |    Aston Villa    | Nottingham Forest |   2.15    |    3.2    |    3.4    |     3.0      |     2.5      |   8.2    |   5.0    |
# | 18 | 2025-04-06 |     Brentford     |      Chelsea      |    3.2    |    2.0    |    3.8    |     2.9      |     2.7      |   6.7    |   5.5    |
# | 19 | 2025-04-06 |      Fulham       |     Liverpool     |    5.0    |    1.6    |    4.2    |     2.7      |     2.9      |   5.5    |   6.7    |
# +----+------------+-------------------+-------------------+-----------+-----------+-----------+--------------+--------------+----------+----------+
